# %% [markdown]
# # 06 - Validacion externa
#
# Objetivo: probar el modelo con imagenes externas o tomadas fuera del dataset de entrenamiento.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
VALIDATION_DIR = PROJECT_ROOT / 'validacion_internet'

EXPECTED = {
    'arbejas.jpg': 'arbejas',
    'arroz.jpg': 'arroz',
    'frijol.jpg': 'frijol'
}

# %% [markdown]
# Este notebook reutiliza la funcion `predict_image` del notebook anterior o puede copiarla aqui si se ejecuta de forma independiente.

# %%
rows = []
# for filename, expected in EXPECTED.items():
#     result = predict_image(VALIDATION_DIR / filename)
#     rows.append({
#         'imagen': filename,
#         'esperado': expected,
#         **result
#     })

pd.DataFrame(rows)
